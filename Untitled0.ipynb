# %% [markdown]
# <a href="https://colab.research.google.com/github/Fenrich04-code/time-series/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('countries.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 40.1+ KB

# %%
import matplotlib.pyplot as plt

brazil = df[df.country == 'Brazil'].copy()
usa = df[df.country == 'United States'].copy()
plt.plot(Brazil.year, Brazil.population)
plt.plot(usa.year, usa.population)
plt.legend(['BR','USA'])

# %%
brazil['population_rel'] = brazil.population/ brazil.iloc[0,2]
usa['population_rel'] = usa.population/ usa.iloc[0,2]
plt.plot(Brazil.year, Brazil.population_rel)
plt.plot(usa.year, usa.population_rel)
plt.legend(['BR','USA'])
